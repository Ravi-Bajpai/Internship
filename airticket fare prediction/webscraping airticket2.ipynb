# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
import time

# %%
from selenium.webdriver.chrome.options import Options

# %%
#disable the notification block from the website
option1=Options()
option1.add_argument("--disable-notifications")

# %%
driver=webdriver.Chrome(r"D:\flip robo\chromedriver_win32\chromedriver.exe",chrome_options=option1)

# %%
url="https://flight.easemytrip.com/"
driver.get(url)

# %%
from selenium.webdriver.common.by import By

# %%
#enter the source airport from where flight has to be taken
#entersource=driver.find_element(By.XPATH,'//input[@class="autoFlll cityinput"]')
#entersource=driver.find_element(By.XPATH,'//input[@id="a_FromSector_show"]')
entersource=driver.find_element(By.XPATH,'//div[@id="frmcity"]')
entersource.click()

# %%
enterfrom=driver.find_element(By.XPATH,'//input[@id="a_FromSector_show"]')
time.sleep(2)

# %%
enterfrom.send_keys("chenn")

# %%
source=driver.find_element(By.XPATH,'//span[@id="spnChennai"]')
source.click()

# %%
destin=driver.find_element(By.XPATH,'//p[@id="ptt"]')
destin.click()

# %%
#entering the destination airport 
enterdestin=driver.find_element(By.XPATH,'//input[@id="a_Editbox13_show"]')

# %%
enterdestin.send_keys("bangalore")

# %%
detinclick=driver.find_element(By.XPATH,'//span[@id="spnBangalore"]')
detinclick.click()

# %%
month=[]
day=[]
date=[]
date_tag=driver.find_element(By.XPATH,'//div[contains(text(),"Apr 18")]')
flightname = driver.find_elements(By.XPATH,'//span[@class="txt-r4 ng-binding"]')
for i in flightname:
    date.append(date_tag.text)
    day.append(date_tag.text.split(' ')[1])
    month.append(date_tag.text.split(' ')[0])

# %%
date[:2]
# Out:
# ['Apr 18', 'Apr 18']

# %%
#function has been define,so that it can be called for different source and destination
def flightticket():
    flightname = driver.find_elements(By.XPATH,'//span[@class="txt-r4 ng-binding"]')
    flight_name=[]
    for i in flightname:
        flight_name.append(i.text)
    airportname_tag = driver.find_elements(By.XPATH,'//span[@class="txt-r3-n ng-binding"]')    
    airportname=[]
    for i in airportname_tag:
        airportname.append(i.text)
    source=[]
    source=airportname[0::2]  
    destination=[]
    destination=airportname[1::2]
    fl_tag = driver.find_elements(By.XPATH,'//span[@class="dura_md ng-binding"]')
    fl=[]
    for i in fl_tag:
        fl.append(i.text)
    st_tag = driver.find_elements(By.XPATH,'//span[@class="dura_md2 ng-scope"]')
    stop=[]
    for i in st_tag:
        stop.append(i.text)
    price_tag = driver.find_elements(By.XPATH,'//div[@class="col-md-2 col-sm-2 col-xs-5 mr5 cle"]')    
    price=[]
    for i in price_tag:
        price.append(i.text.split('\n')[0])
    fltime_tag=driver.find_elements(By.XPATH,'//span[@class="txt-r2-n ng-binding"]')    
    fltime=[]
    for i in fltime_tag:
        fltime.append(i.text)
    departure=[]
    departure=fltime[0::2] 
    arrival=[]
    arrival=fltime[1::2]
    df1=pd.DataFrame()
    df1['FLIGHT NAME']=flight_name
    df1['SOURCE']=source
    df1['DESTINATION']=destination
    df1['ARRIVAL']=arrival
    df1['DEPARTURE']=departure
    df1['TIME OF TRAVEL']=fl
    df1['NO. OF STOP']=stop
    df1['PRICE']=price
    return(df1)

# %%
df1=flightticket()
df1["DATE"]=date
dffinal=pd.DataFrame()
dffinal=dffinal.append(df1,ignore_index = True)

# %%
dffinal
# Out:
#    FLIGHT NAME   SOURCE DESTINATION ARRIVAL DEPARTURE TIME OF TRAVEL  \
# 0      AirAsia  Chennai   Bangalore   13:50     12:55        00h 55m
# 1      AirAsia  Chennai   Bangalore   08:10     07:10        01h 00m
# 2      AirAsia  Chennai   Bangalore   22:55     21:50        01h 05m
# 3       Indigo  Chennai   Bangalore   12:15     11:20        00h 55m
# 4       Indigo  Chennai   Bangalore   08:30     07:40        00h 50m
# ..         ...      ...         ...     ...       ...            ...
# 61     Vistara  Chennai   Bangalore   18:20     11:20        31h 00m
# 62     Vistara  Chennai   Bangalore   18:20     07:05        35h 15m
# 63     Vistara  Chennai   Bangalore   18:20     09:30        32h 50m
# 64     Vistara  Chennai   Bangalore   18:20     07:00        35h 20m
# 65     Vistara  Chennai   Bangalore   18:20     20:30        21h 50m
#
#    NO. OF STOP   PRICE    DATE
# 0     non-stop   1,718  Apr 18
# 1     non-stop   1,933  Apr 18
# 2     non-stop   1,933  Apr 18
# 3     non-stop   1,825  Apr 18
# 4     non-stop   2,040  Apr 18
# ..         ...     ...     ...
# 61      1-stop  17,340  Apr 18
# 62      1-stop  17,392  Apr 18
# 63      1-stop  17,916  Apr 18
# 64      1-stop  17,916  Apr 18
# 65      1-stop  17,969  Apr 18
#
# [66 rows x 9 columns]

# %%
dffinal.to_csv("fight222.csv")

# %%
entersource=driver.find_element(By.XPATH,'//input[@id="FromSector_show"]')
entersource.click()

# %%
entersource.send_keys("chennai")

# %%
source=driver.find_element(By.XPATH,'/html/body/form/div[10]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[1]/div[3]/div/div/div/ul/li[7]/div[1]/span[2]')
source.click()

# %%
enterdestin=driver.find_element(By.XPATH,'//input[@id="Editbox13_show"]')
enterdestin.click()

# %%
enterdestin.send_keys("mumbai")

# %%
searchbtn=driver.find_element(By.XPATH,'/html/body/form/div[10]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[3]/button[1]')

# %%
date1=[]
flightname = driver.find_elements(By.XPATH,'//span[@class="txt-r4 ng-binding"]')
for i in flightname:
    date1.append("27 May 2023")

# %%
df2=flightticket()
df2["DATE"]=date1
dffinal=dffinal.append(df2,ignore_index = True)

# %%
dffinal
# Out:
#     FLIGHT NAME   SOURCE DESTINATION ARRIVAL DEPARTURE TIME OF TRAVEL  \
# 0       AirAsia  Chennai   Bangalore   13:50     12:55        00h 55m
# 1       AirAsia  Chennai   Bangalore   08:10     07:10        01h 00m
# 2       AirAsia  Chennai   Bangalore   22:55     21:50        01h 05m
# 3        Indigo  Chennai   Bangalore   12:15     11:20        00h 55m
# 4        Indigo  Chennai   Bangalore   08:30     07:40        00h 50m
# ..          ...      ...         ...     ...       ...            ...
# 187     Vistara  Chennai      Mumbai   19:05     07:05        12h 00m
# 188   Air India  Chennai      Mumbai   22:05     20:30        25h 35m
# 189     Vistara  Chennai      Mumbai   20:05     21:05        23h 00m
# 190     Vistara  Chennai      Mumbai   21:15     21:05        24h 10m
# 191     Vistara  Chennai      Mumbai   22:00     11:20        10h 40m
#
#     NO. OF STOP   PRICE         DATE
# 0      non-stop   1,718       Apr 18
# 1      non-stop   1,933       Apr 18
# 2      non-stop   1,933       Apr 18
# 3      non-stop   1,825       Apr 18
# 4      non-stop   2,040       Apr 18
# ..          ...     ...          ...
# 187      1-stop  24,880  27 May 2023
# 188      1-stop  25,636  27 May 2023
# 189      1-stop  29,028  27 May 2023
# 190      1-stop  29,080  27 May 2023
# 191      1-stop  49,508  27 May 2023
#
# [192 rows x 9 columns]

# %%
dffinal.to_csv("fight223.csv")

# %%
entersource=driver.find_element(By.XPATH,'//input[@id="FromSector_show"]')
entersource.click()

# %%
entersource.send_keys("hyderabad")

# %%
enterdestin=driver.find_element(By.XPATH,'//input[@id="Editbox13_show"]')
enterdestin.click()

# %%
enterdestin.send_keys("chennai")

# %%
searchbtn=driver.find_element(By.XPATH,'/html/body/form/div[10]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[3]/button[1]')
searchbtn.click()

# %%
date2=[]
flightname = driver.find_elements(By.XPATH,'//span[@class="txt-r4 ng-binding"]')
for i in flightname:
    date2.append("10 June 2023")

# %%
df3=flightticket()
df3["DATE"]=date2
dffinal=dffinal.append(df3,ignore_index = True)

# %%
dffinal
# Out:
#      FLIGHT NAME     SOURCE DESTINATION ARRIVAL DEPARTURE TIME OF TRAVEL  \
# 0        AirAsia    Chennai   Bangalore   13:50     12:55        00h 55m
# 1        AirAsia    Chennai   Bangalore   08:10     07:10        01h 00m
# 2        AirAsia    Chennai   Bangalore   22:55     21:50        01h 05m
# 3         Indigo    Chennai   Bangalore   12:15     11:20        00h 55m
# 4         Indigo    Chennai   Bangalore   08:30     07:40        00h 50m
# ..           ...        ...         ...     ...       ...            ...
# 294    Air India  Hyderabad     Chennai   08:50     16:25        16h 25m
# 295    Air India  Hyderabad     Chennai   23:35     06:15        17h 20m
# 296    Air India  Hyderabad     Chennai   08:50     14:10        18h 40m
# 297    Air India  Hyderabad     Chennai   19:15     20:40        22h 35m
# 298  AllianceAir  Hyderabad     Chennai   09:35     07:50        01h 45m
#
#     NO. OF STOP   PRICE          DATE
# 0      non-stop   1,718        Apr 18
# 1      non-stop   1,933        Apr 18
# 2      non-stop   1,933        Apr 18
# 3      non-stop   1,825        Apr 18
# 4      non-stop   2,040        Apr 18
# ..          ...     ...           ...
# 294      1-stop  13,403  10 June 2023
# 295      1-stop  13,403  10 June 2023
# 296      1-stop  13,403  10 June 2023
# 297      1-stop  13,403  10 June 2023
# 298    non-stop  22,381  10 June 2023
#
# [299 rows x 9 columns]

# %%
dffinal.to_csv("fight224.csv")

# %%
entersource=driver.find_element(By.XPATH,'//input[@id="FromSector_show"]')
entersource.click()

# %%
entersource.send_keys("Delhi")

# %%
enterdestin=driver.find_element(By.XPATH,'//input[@id="Editbox13_show"]')
enterdestin.click()

# %%
enterdestin.send_keys("Kolkata")

# %%
searchbtn=driver.find_element(By.XPATH,'/html/body/form/div[10]/div[2]/div/div[4]/div/div/div[1]/div/div[1]/div[3]/button[1]')
searchbtn.click()

# %%
date3=[]
flightname = driver.find_elements(By.XPATH,'//span[@class="txt-r4 ng-binding"]')
for i in flightname:
    date3.append("2 June 2023")

# %%
df4=flightticket()
df4["DATE"]=date3
dffinal=dffinal.append(df4,ignore_index = True)

# %%
dffinal
# Out:
#     FLIGHT NAME   SOURCE DESTINATION ARRIVAL DEPARTURE TIME OF TRAVEL  \
# 0       AirAsia  Chennai   Bangalore   13:50     12:55        00h 55m
# 1       AirAsia  Chennai   Bangalore   08:10     07:10        01h 00m
# 2       AirAsia  Chennai   Bangalore   22:55     21:50        01h 05m
# 3        Indigo  Chennai   Bangalore   12:15     11:20        00h 55m
# 4        Indigo  Chennai   Bangalore   08:30     07:40        00h 50m
# ..          ...      ...         ...     ...       ...            ...
# 421     Vistara    Delhi     Kolkata   19:50     16:50        27h 00m
# 422     AirAsia    Delhi     Kolkata   15:25     10:40        04h 45m
# 423     AirAsia    Delhi     Kolkata   15:25     09:25        06h 00m
# 424    SpiceJet    Delhi     Kolkata   10:25     05:45        04h 40m
# 425     Vistara    Delhi     Kolkata   09:45     17:40        16h 05m
#
#     NO. OF STOP   PRICE         DATE
# 0      non-stop   1,718       Apr 18
# 1      non-stop   1,933       Apr 18
# 2      non-stop   1,933       Apr 18
# 3      non-stop   1,825       Apr 18
# 4      non-stop   2,040       Apr 18
# ..          ...     ...          ...
# 421      1-stop  23,637  2 June 2023
# 422      1-stop  24,687  2 June 2023
# 423      1-stop  24,687  2 June 2023
# 424      1-stop  26,508  2 June 2023
# 425     2+-stop  32,305  2 June 2023
#
# [426 rows x 9 columns]

# %%
dffinal.to_csv('fight225.csv')

# %% [markdown]
# # MAKEMY TRIP

# %%
driver=webdriver.Chrome(r'D:\flip robo\chromedriver_win32\chromedriver.exe')

# %%
url="https://www.makemytrip.com/flights/"
driver.get(url)

# %%
entersource=driver.find_element(By.XPATH,'//span[@class="lbl_input appendBottom10"]')
entersource.click()

# %%
source=driver.find_element(By.XPATH,'//body/div[@id="root"]/div[1]/div[2]/div[1]/div[1]/div[2]/div[1]/div[1]/div[1]/div[1]/div[1]/div[1]/input[1]')

# %%
source.send_keys("bangolore")

# %%
source1=driver.find_element(By.XPATH,'//p[contains(text(),"Bengaluru, India")]')
source1.click()

# %%
enterdestin=driver.find_element(By.XPATH,'//input[@data-cy="toCity"]')
enterdestin.click()

# %%
destin=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[2]/div/div/div[2]/div[1]/div[2]/div[2]/div/div/div[1]/input')

# %%
destin.send_keys("thiruvananthpuram")

# %%
def makemytrip():
    allinfo = driver.find_elements(By.XPATH,'//div[@class="makeFlex simpleow"]')
    airlinename=[]
    departure=[]
    source=[]
    timeofjourney=[]
    stop=[]
    arrival=[]
    destination=[]
    price=[]
    allinform=[]
    for i in allinfo:
        allinform.append(i.text)
        airlinename.append(i.text.split('\n')[0])
        departure.append(i.text.split('\n')[2])
        source.append(i.text.split('\n')[3])
        timeofjourney.append(i.text.split('\n')[4])
        stop.append(i.text.split('\n')[5])
        arrival.append(i.text.split('\n')[6])
        destination.append(i.text.split('\n')[7])
        price.append(i.text.split('\n')[8])
    df2=pd.DataFrame()
    df2['FLIGHT NAME']=airlinename
    df2['SOURCE']=source
    df2['DESTINATION']=destination
    df2['ARRIVAL']=arrival
    df2['DEPARTURE']=departure
    df2['TIME OF TRAVEL']=timeofjourney
    df2['NO. OF STOP']=stop
    df2['PRICE']=price                  
    return(df2)

# %%
date4=[]
allinfo = driver.find_elements(By.XPATH,'//div[@class="makeFlex simpleow"]')
for i in allinfo:
    date4.append("8 April 2023")

# %%
df5=makemytrip()
df5["DATE"]=date4
dffinal=dffinal.append(df5,ignore_index = True)

# %%
dffinal
# Out:
#     FLIGHT NAME     SOURCE         DESTINATION ARRIVAL DEPARTURE  \
# 0       AirAsia    Chennai           Bangalore   13:50     12:55
# 1       AirAsia    Chennai           Bangalore   08:10     07:10
# 2       AirAsia    Chennai           Bangalore   22:55     21:50
# 3        Indigo    Chennai           Bangalore   12:15     11:20
# 4        Indigo    Chennai           Bangalore   08:30     07:40
# ..          ...        ...                 ...     ...       ...
# 441   Air India  Bengaluru  Thiruvananthapuram   20:05     09:20
# 442   Air India  Bengaluru  Thiruvananthapuram   20:05     06:45
# 443   Air India  Bengaluru  Thiruvananthapuram   20:05     14:35
# 444   Air India  Bengaluru             + 1 DAY   00:50     17:15
# 445     Vistara  Bengaluru             + 1 DAY   11:40     21:10
#
#     TIME OF TRAVEL           NO. OF STOP               PRICE          DATE
# 0          00h 55m              non-stop               1,718        Apr 18
# 1          01h 00m              non-stop               1,933        Apr 18
# 2          01h 05m              non-stop               1,933        Apr 18
# 3          00h 55m              non-stop               1,825        Apr 18
# 4          00h 50m              non-stop               2,040        Apr 18
# ..             ...                   ...                 ...           ...
# 441      10 h 45 m     1 stop via Mumbai            ₹ 11,328  8 April 2023
# 442      13 h 20 m     1 stop via Mumbai            ₹ 11,328  8 April 2023
# 443      05 h 30 m     1 stop via Mumbai            ₹ 12,483  8 April 2023
# 444      07 h 35 m  1 stop via New Delhi  Thiruvananthapuram  8 April 2023
# 445      14 h 30 m  1 stop via New Delhi  Thiruvananthapuram  8 April 2023
#
# [446 rows x 9 columns]

# %%
dffinal.to_csv('fight226.csv')

# %%
entersource1=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[2]/header/div[1]/div/div[2]/div[1]/form/div/input')
entersource1.click()

# %%
entersource1.send_keys("Delhi")

# %%
enterdestin=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[2]/header/div[1]/div/div[4]/div[1]/form/div/input')
enterdestin.click()

# %%
enterdestin.send_keys("bengaluru")

# %%
date5=[]
allinfo = driver.find_elements(By.XPATH,'//div[@class="makeFlex simpleow"]')
for i in allinfo:
    date5.append("24 April 2023")

# %%
df6=makemytrip()
df6["DATE"]=date5
dffinal=dffinal.append(df6,ignore_index = True)

# %%
dffinal
# Out:
#     FLIGHT NAME     SOURCE DESTINATION ARRIVAL DEPARTURE TIME OF TRAVEL  \
# 0       AirAsia    Chennai   Bangalore   13:50     12:55        00h 55m
# 1       AirAsia    Chennai   Bangalore   08:10     07:10        01h 00m
# 2       AirAsia    Chennai   Bangalore   22:55     21:50        01h 05m
# 3        Indigo    Chennai   Bangalore   12:15     11:20        00h 55m
# 4        Indigo    Chennai   Bangalore   08:30     07:40        00h 50m
# ..          ...        ...         ...     ...       ...            ...
# 467   Air India  New Delhi   Bengaluru   06:25     03:30      02 h 55 m
# 468   Air India  New Delhi   Bengaluru   12:30     09:40      02 h 50 m
# 469   Air India  New Delhi   Bengaluru   16:20     13:30      02 h 50 m
# 470   Air India  New Delhi   Bengaluru   18:35     15:35           03 h
# 471   Akasa Air  New Delhi   Bengaluru   23:55     21:20      02 h 35 m
#
#     NO. OF STOP    PRICE           DATE
# 0      non-stop    1,718         Apr 18
# 1      non-stop    1,933         Apr 18
# 2      non-stop    1,933         Apr 18
# 3      non-stop    1,825         Apr 18
# 4      non-stop    2,040         Apr 18
# ..          ...      ...            ...
# 467    Non stop  ₹ 5,504  24 April 2023
# 468    Non stop  ₹ 5,504  24 April 2023
# 469    Non stop  ₹ 5,504  24 April 2023
# 470    Non stop  ₹ 5,504  24 April 2023
# 471    Non stop  ₹ 5,577  24 April 2023
#
# [472 rows x 9 columns]

# %%
dffinal.to_csv('fight227.csv')

# %%
entersource2=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[2]/header/div[1]/div/div[2]/div[1]/form/div/input')
entersource2.click()

# %%
entersource2.send_keys("Delhi")

# %%
enterdestin1=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[2]/header/div[1]/div/div[4]/div[1]/form/div/input')
enterdestin1.click()

# %%
enterdestin1.send_keys("Chennai")

# %%
date6=[]
allinfo = driver.find_elements(By.XPATH,'//div[@class="makeFlex simpleow"]')
for i in allinfo:
    date6.append("7 May 2023")

# %%
df7=makemytrip()
df7["DATE"]=date6
dffinal=dffinal.append(df7,ignore_index = True)

# %%
dffinal
# Out:
#          FLIGHT NAME     SOURCE DESTINATION ARRIVAL DEPARTURE TIME OF TRAVEL  \
# 0            AirAsia    Chennai   Bangalore   13:50     12:55        00h 55m
# 1            AirAsia    Chennai   Bangalore   08:10     07:10        01h 00m
# 2            AirAsia    Chennai   Bangalore   22:55     21:50        01h 05m
# 3             Indigo    Chennai   Bangalore   12:15     11:20        00h 55m
# 4             Indigo    Chennai   Bangalore   08:30     07:40        00h 50m
# ..               ...        ...         ...     ...       ...            ...
# 484           IndiGo  New Delhi     Chennai   18:45     15:55      02 h 50 m
# 485           IndiGo  New Delhi     Chennai   21:45     18:55      02 h 50 m
# 486  AirAsia, IndiGo  New Delhi     + 1 DAY   00:50     18:50           06 h
# 487          Vistara  New Delhi     Chennai   10:10     07:20      02 h 50 m
# 488        Air India  New Delhi     Chennai   14:20     09:40      04 h 40 m
#
#               NO. OF STOP    PRICE        DATE
# 0                non-stop    1,718      Apr 18
# 1                non-stop    1,933      Apr 18
# 2                non-stop    1,933      Apr 18
# 3                non-stop    1,825      Apr 18
# 4                non-stop    2,040      Apr 18
# ..                    ...      ...         ...
# 484              Non stop  ₹ 8,523  7 May 2023
# 485              Non stop  ₹ 8,572  7 May 2023
# 486  1 stop via Bengaluru  Chennai  7 May 2023
# 487              Non stop  ₹ 8,653  7 May 2023
# 488  1 stop via Bengaluru  ₹ 8,727  7 May 2023
#
# [489 rows x 9 columns]

# %%
dffinal.to_csv('fight228.csv')

# %%
entersource3=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[2]/header/div[1]/div/div[2]/div[1]/form/div/input')
entersource3.click()

# %%
entersource3.send_keys("Delhi")

# %%
enterdestin2=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[2]/header/div[1]/div/div[4]/div[1]/form/div/input')
enterdestin2.click()

# %%
enterdestin2.send_keys("Hyderabad")

# %%
date7=[]
allinfo = driver.find_elements(By.XPATH,'//div[@class="makeFlex simpleow"]')
for i in allinfo:
    date7.append("8 June 2023")

# %%
df8=makemytrip()
df8["DATE"]=date7
dffinal=dffinal.append(df8,ignore_index = True)

# %%
dffinal
# Out:
#     FLIGHT NAME     SOURCE DESTINATION ARRIVAL DEPARTURE TIME OF TRAVEL  \
# 0       AirAsia    Chennai   Bangalore   13:50     12:55        00h 55m
# 1       AirAsia    Chennai   Bangalore   08:10     07:10        01h 00m
# 2       AirAsia    Chennai   Bangalore   22:55     21:50        01h 05m
# 3        Indigo    Chennai   Bangalore   12:15     11:20        00h 55m
# 4        Indigo    Chennai   Bangalore   08:30     07:40        00h 50m
# ..          ...        ...         ...     ...       ...            ...
# 513      IndiGo  New Delhi   Hyderabad   23:40     21:25      02 h 15 m
# 514     AirAsia  New Delhi   Hyderabad   14:10     08:20      05 h 50 m
# 515     Vistara  New Delhi   Hyderabad   19:50     17:40      02 h 10 m
# 516   Air India  New Delhi   Hyderabad   07:30     01:45      05 h 45 m
# 517   Air India  New Delhi   Hyderabad   19:10     17:00      02 h 10 m
#
#               NO. OF STOP     PRICE         DATE
# 0                non-stop     1,718       Apr 18
# 1                non-stop     1,933       Apr 18
# 2                non-stop     1,933       Apr 18
# 3                non-stop     1,825       Apr 18
# 4                non-stop     2,040       Apr 18
# ..                    ...       ...          ...
# 513              Non stop   ₹ 7,844  8 June 2023
# 514  1 stop via Bengaluru   ₹ 7,944  8 June 2023
# 515              Non stop   ₹ 8,885  8 June 2023
# 516     1 stop via Mumbai   ₹ 8,895  8 June 2023
# 517              Non stop  ₹ 13,830  8 June 2023
#
# [518 rows x 9 columns]

# %%
dffinal.to_csv('fight229.csv')

# %%
entersource4=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[2]/header/div[1]/div/div[2]/div[1]/form/div/input')
entersource4.click()

# %%
entersource4.send_keys("Mumbai")

# %%
enterdestin3=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[2]/header/div[1]/div/div[4]/div[1]/form/div/input')
enterdestin3.click()

# %%
enterdestin3.send_keys("Goa")

# %%
date8=[]
allinfo = driver.find_elements(By.XPATH,'//div[@class="makeFlex simpleow"]')
for i in allinfo:
    date8.append("19 June 2023")

# %%
df9=makemytrip()
df9["DATE"]=date8
dffinal=dffinal.append(df9,ignore_index = True)

# %%
dffinal
# Out:
#     FLIGHT NAME   SOURCE                 DESTINATION ARRIVAL DEPARTURE  \
# 0       AirAsia  Chennai                   Bangalore   13:50     12:55
# 1       AirAsia  Chennai                   Bangalore   08:10     07:10
# 2       AirAsia  Chennai                   Bangalore   22:55     21:50
# 3        Indigo  Chennai                   Bangalore   12:15     11:20
# 4        Indigo  Chennai                   Bangalore   08:30     07:40
# ..          ...      ...                         ...     ...       ...
# 543    SpiceJet   Mumbai       Goa - Dabolim Airport   16:30     15:15
# 544    SpiceJet   Mumbai  Goa (North) - Mopa Airport   09:50     08:45
# 545     Vistara   Mumbai                     + 1 DAY   14:00     21:30
# 546    SpiceJet   Mumbai                     + 1 DAY   01:00     23:50
# 547     Vistara   Mumbai  Goa (North) - Mopa Airport   12:30     07:00
#
#     TIME OF TRAVEL           NO. OF STOP                               PRICE  \
# 0          00h 55m              non-stop                               1,718
# 1          01h 00m              non-stop                               1,933
# 2          01h 05m              non-stop                               1,933
# 3          00h 55m              non-stop                               1,825
# 4          00h 50m              non-stop                               2,040
# ..             ...                   ...                                 ...
# 543      01 h 15 m              Non stop                             ₹ 5,924
# 544      01 h 05 m              Non stop  (43 KM from Goa - Dabolim Airport)
# 545      16 h 30 m  1 stop via Bengaluru               Goa - Dabolim Airport
# 546      01 h 10 m              Non stop               Goa - Dabolim Airport
# 547      05 h 30 m  1 stop via Bengaluru  (43 KM from Goa - Dabolim Airport)
#
#              DATE
# 0          Apr 18
# 1          Apr 18
# 2          Apr 18
# 3          Apr 18
# 4          Apr 18
# ..            ...
# 543  19 June 2023
# 544  19 June 2023
# 545  19 June 2023
# 546  19 June 2023
# 547  19 June 2023
#
# [548 rows x 9 columns]

# %%
dffinal.to_csv('fight300.csv')

# %% [markdown]
# # PAYTM

# %%
driver=webdriver.Chrome(r'D:\flip robo\chromedriver_win32\chromedriver.exe')

# %%
url="https://tickets.paytm.com/"
driver.get(url)

# %%
from selenium.webdriver.common.by import By

# %%
flight1=driver.find_elements(By.XPATH,'//div[@class="_3215 row"]')

# %%
flight_name1=[]
for i in flight1:
    flight_name1.append(i.text)

# %%
flight_name1
# Out:
# ['Akasa Air\nQP - 1312\nFlight Details\n07:30\nPune\n-\n09:10\nBengaluru\n1h 40m\nNon Stop\n2,896\nBook',
#  'IndiGo\n6E - 6336\nFlight Details\n04:35\nPune\n-\n05:55\nBengaluru\n1h 20m\nNon Stop\n2,898\nBook',
#  'IndiGo\n6E - 6886\nFlight Details\n20:40\nPune\n-\n22:10\nBengaluru\n1h 30m\nNon Stop\n2,898\nBook',
#  'IndiGo\n6E - 391\nFlight Details\n07:25\nPune\n-\n09:00\nBengaluru\n1h 35m\nNon Stop\n2,898\nBook',
#  'IndiGo\n6E - 6406\nFlight Details\n00:40\nPune\n-\n02:15\nBengaluru\n1h 35m\nNon Stop\n2,898\nBook',
#  'IndiGo\n6E - 338\nFlight Details\n02:55\nPune\n-\n04:30\nBengaluru\n1h 35m\nNon Stop\n2,898\nBook',
#  'IndiGo\n6E - 6055\nFlight Details\n18:55\nPune\n-\n20:30\nBengaluru\n1h 35m\nNon Stop\n2,898\nBook',
#  'Akasa Air\nQP - 1318\nFlight Details\n23:50\nPune\n-\n01:20\nBengaluru\narrives next day\n1h 30m\nNon Stop\n2,942\nBook',
#  'Air Asia\nI5 - 975\nFlight Details\n01:55\nPune\n-\n03:20\nBengaluru\n1h 25m\nNon Stop\n3,003\nBook',
#  'Air Asia\nI5 - 1427\nFlight Details\n19:25\nPune\n-\n20:55\nBengaluru\n1h 30m\nNon Stop\n3,003\nBook',
#  'Go First\nG8 - 242\nFlight Details\n20:50\nPune\n-\n22:15\nBengaluru\n1h 25m\nNon Stop\n3,204\nBook',
#  'Akasa Air\nQP - 1365\nFlight Details\n17:30\nPune\n-\n19:00\nBengaluru\n1h 30m\nNon Stop\n3,249\nBook',
#  'IndiGo\n6E - 629\nFlight Details\n13:50\nPune\n-\n15:30\nBengaluru\n1h 40m\nNon Stop\n3,318\nBook',
#  'Air Asia\nI5 - 611\nFlight Details\n05:25\nPune\n-\n07:00\nBengaluru\n1h 35m\nNon Stop\n3,739\nBook',
#  'Air India\nAI - 614\nFlight Details\n11:20\nPune\n-\n18:20\nBengaluru\n7h\n1 stop at Mumbai\n5,282\nBook',
#  'Air India\nAI - 614\nFlight Details\n11:20\nPune\n-\n05:50\nBengaluru\narrives next day\n18h 30m\n1 stop at Mumbai\n5,282\nBook',
#  'Air India\nAI - 614\nFlight Details\n11:20\nPune\n-\n14:00\nBengaluru\narrives next day\n26h 40m\n1 stop at Mumbai\n5,282\nBook',
#  'IndiGo\n6E - 672\nFlight Details\n00:05\nPune\n-\n07:50\nBengaluru\n7h 45m\n1 stop at Mangalore\n5,499\nBook',
#  'Air India\nAI - 614\nFlight Details\n11:20\nPune\n-\n20:25\nBengaluru\n9h 5m\n1 stop at Mumbai\n5,807\nBook',
#  'IndiGo\n6E - 159\nFlight Details\n05:40\nPune\n-\n09:50\nBengaluru\n4h 10m\n1 stop at Chennai\n6,423\nBook',
#  'IndiGo\n6E - 105\nFlight Details\n17:45\nPune\n-\n23:05\nBengaluru\n5h 20m\n1 stop at Chennai\n6,423\nBook',
#  'IndiGo\n6E - 553\nFlight Details\n01:05\nPune\n-\n08:30\nBengaluru\n7h 25m\n1 stop at Chennai\n6,423\nBook',
#  'IndiGo\n6E - 988\nFlight Details\n14:50\nPune\n-\n23:05\nBengaluru\n8h 15m\n1 stop at Chennai\n6,423\nBook',
#  'IndiGo\n6E - 553\nFlight Details\n01:05\nPune\n-\n09:50\nBengaluru\n8h 45m\n1 stop at Chennai\n6,423\nBook',
#  'IndiGo\n6E - 6476\nFlight Details\n04:30\nPune\n-\n09:05\nBengaluru\n4h 35m\n1 stop at Coimbatore\n6,529\nBook',
#  'IndiGo\n6E - 6476\nFlight Details\n04:30\nPune\n-\n12:35\nBengaluru\n8h 5m\n1 stop at Coimbatore\n6,529\nBook',
#  'IndiGo\n6E - 988\nFlight Details\n14:50\nPune\n-\n20:20\nBengaluru\n5h 30m\n1 stop at Chennai\n6,622\nBook',
#  'IndiGo\n6E - 159\nFlight Details\n05:40\nPune\n-\n12:15\nBengaluru\n6h 35m\n1 stop at Chennai\n6,622\nBook',
#  'IndiGo\n6E - 672\nFlight Details\n00:05\nPune\n-\n10:20\nBengaluru\n10h 15m\n1 stop at Mangalore\n6,692\nBook',
#  'Air India\nAI - 614\nFlight Details\n11:20\nPune\n-\n08:40\nBengaluru\narrives next day\n21h 20m\n1 stop at Mumbai\n6,857\nBook',
#  'Air India\nAI - 614\nFlight Details\n11:20\nPune\n-\n11:10\nBengaluru\narrives next day\n23h 50m\n1 stop at Mumbai\n6,857\nBook',
#  'IndiGo\n6E - 988\nFlight Details\n14:50\nPune\n-\n18:55\nBengaluru\n4h 5m\n1 stop at Chennai\n6,923\nBook',
#  'IndiGo\n6E - 159\nFlight Details\n05:40\nPune\n-\n14:15\nBengaluru\n8h 35m\n1 stop at Chennai\n6,923\nBook',
#  'IndiGo\n6E - 103\nFlight Details\n22:30\nPune\n-\n06:45\nBengaluru\narrives next day\n8h 15m\n1 stop at Hyderabad\n7,042\nBook',
#  'IndiGo\n6E - 103\nFlight Details\n22:30\nPune\n-\n08:25\nBengaluru\narrives next day\n9h 55m\n1 stop at Hyderabad\n7,042\nBook',
#  'IndiGo\n6E - 6186\nFlight Details\n21:55\nPune\n-\n08:30\nBengaluru\narrives next day\n10h 35m\n1 stop at Chennai\n7,077\nBook',
#  'IndiGo\n6E - 6944\nFlight Details\n05:55\nPune\n-\n13:25\nBengaluru\n7h 30m\n1 stop at Goa\n7,098\nBook',
#  'IndiGo\n6E - 6297\nFlight Details\n03:35\nPune\n-\n08:25\nBengaluru\n4h 50m\n1 stop at Hyderabad\n8,403\nBook',
#  'IndiGo\n6E - 352\nFlight Details\n06:25\nPune\n-\n10:30\nBengaluru\n4h 5m\n1 stop at Hyderabad\n8,497\nBook',
#  'IndiGo\n6E - 352\nFlight Details\n06:25\nPune\n-\n13:00\nBengaluru\n6h 35m\n1 stop at Hyderabad\n8,497\nBook',
#  'IndiGo\n6E - 6297\nFlight Details\n03:35\nPune\n-\n09:45\nBengaluru\n6h 10m\n1 stop at Hyderabad\n8,803\nBook',
#  'IndiGo\n6E - 6297\nFlight Details\n03:35\nPune\n-\n10:30\nBengaluru\n6h 55m\n1 stop at Hyderabad\n8,803\nBook',
#  'IndiGo\n6E - 6297\nFlight Details\n03:35\nPune\n-\n13:00\nBengaluru\n9h 25m\n1 stop at Hyderabad\n8,803\nBook',
#  'IndiGo\n6E - 302\nFlight Details\n13:55\nPune\n-\n23:55\nBengaluru\n10h\n1 stop at Hyderabad\n9,479\nBook',
#  'IndiGo\n6E - 302\nFlight Details\n13:55\nPune\n-\n18:10\nBengaluru\n4h 15m\n1 stop at Hyderabad\n9,878\nBook',
#  'IndiGo\n6E - 302\nFlight Details\n13:55\nPune\n-\n19:05\nBengaluru\n5h 10m\n1 stop at Hyderabad\n9,878\nBook',
#  'IndiGo\n6E - 302\nFlight Details\n13:55\nPune\n-\n22:10\nBengaluru\n8h 15m\n1 stop at Hyderabad\n9,878\nBook',
#  'SpiceJet\nSG - 525\nFlight Details\n12:30\nPune\n-\n23:50\nBengaluru\n11h 20m\n1 stop at Goa\n10,089\nBook',
#  'Air India\nAI - 850\nFlight Details\n18:50\nPune\n-\n06:25\nBengaluru\narrives next day\n11h 35m\n1 stop at Delhi\n11,025\nBook',
#  'Air India\nAI - 850\nFlight Details\n18:50\nPune\n-\n09:00\nBengaluru\narrives next day\n14h 10m\n1 stop at Delhi\n11,025\nBook',
#  'Air India\nAI - 850\nFlight Details\n18:50\nPune\n-\n10:55\nBengaluru\narrives next day\n16h 5m\n1 stop at Delhi\n11,025\nBook',
#  'Air India\nAI - 850\nFlight Details\n18:50\nPune\n-\n20:15\nBengaluru\narrives next day\n25h 25m\n1 stop at Delhi\n11,025\nBook',
#  'Air India\nAI - 482\nFlight Details\n12:40\nPune\n-\n06:25\nBengaluru\narrives next day\n17h 45m\n2 Stops (AMD, DEL)\n11,372\nBook',
#  'Air India\nAI - 482\nFlight Details\n12:40\nPune\n-\n09:00\nBengaluru\narrives next day\n20h 20m\n2 Stops (AMD, DEL)\n11,372\nBook',
#  'Air India\nAI - 482\nFlight Details\n12:40\nPune\n-\n10:55\nBengaluru\narrives next day\n22h 15m\n2 Stops (AMD, DEL)\n11,372\nBook',
#  'Air India\nAI - 852\nFlight Details\n07:40\nPune\n-\n06:25\nBengaluru\narrives next day\n22h 45m\n1 stop at Delhi\n11,372\nBook',
#  'Air India\nAI - 852\nFlight Details\n07:40\nPune\n-\n09:00\nBengaluru\narrives next day\n25h 20m\n1 stop at Delhi\n11,372\nBook',
#  'Air India\nAI - 852\nFlight Details\n07:40\nPune\n-\n10:55\nBengaluru\narrives next day\n27h 15m\n1 stop at Delhi\n11,372\nBook',
#  'Vistara\nUK - 998\nFlight Details\n16:55\nPune\n-\n09:05\nBengaluru\narrives next day\n16h 10m\n1 stop at Delhi\n11,821\nBook',
#  'Air India\nAI - 850\nFlight Details\n18:50\nPune\n-\n12:30\nBengaluru\narrives next day\n17h 40m\n1 stop at Delhi\n11,865\nBook',
#  'Air India\nAI - 850\nFlight Details\n18:50\nPune\n-\n16:20\nBengaluru\narrives next day\n21h 30m\n1 stop at Delhi\n11,865\nBook',
#  'Vistara\nUK - 992\nFlight Details\n20:20\nPune\n-\n09:05\nBengaluru\narrives next day\n12h 45m\n1 stop at Delhi\n11,873\nBook',
#  'Vistara\nUK - 992\nFlight Details\n20:20\nPune\n-\n22:40\nBengaluru\narrives next day\n26h 20m\n1 stop at Delhi\n12,031\nBook',
#  'Air India\nAI - 852\nFlight Details\n07:40\nPune\n-\n18:35\nBengaluru\n10h 55m\n1 stop at Delhi\n12,212\nBook',
#  'Air India\nAI - 482\nFlight Details\n12:40\nPune\n-\n00:05\nBengaluru\narrives next day\n11h 25m\n2 Stops (AMD, DEL)\n12,212\nBook',
#  'Air India\nAI - 852\nFlight Details\n07:40\nPune\n-\n00:05\nBengaluru\narrives next day\n16h 25m\n1 stop at Delhi\n12,212\nBook',
#  'Vistara\nUK - 998\nFlight Details\n16:55\nPune\n-\n23:20\nBengaluru\n6h 25m\n1 stop at Delhi\n12,766\nBook',
#  'Vistara\nUK - 992\nFlight Details\n20:20\nPune\n-\n11:50\nBengaluru\narrives next day\n15h 30m\n1 stop at Delhi\n12,766\nBook',
#  'Vistara\nUK - 998\nFlight Details\n16:55\nPune\n-\n10:50\nBengaluru\narrives next day\n17h 55m\n1 stop at Delhi\n12,766\nBook',
#  'Vistara\nUK - 992\nFlight Details\n20:20\nPune\n-\n10:50\nBengaluru\narrives next day\n14h 30m\n1 stop at Delhi\n12,818\nBook',
#  'Vistara\nUK - 992\nFlight Details\n20:20\nPune\n-\n18:45\nBengaluru\narrives next day\n22h 25m\n1 stop at Delhi\n12,923\nBook',
#  'Air India\nAI - 482\nFlight Details\n12:40\nPune\n-\n20:15\nBengaluru\n7h 35m\n2 Stops (AMD, DEL)\n13,052\nBook',
#  'Air India\nAI - 852\nFlight Details\n07:40\nPune\n-\n16:20\nBengaluru\n8h 40m\n1 stop at Delhi\n13,052\nBook',
#  'Air India\nAI - 852\nFlight Details\n07:40\nPune\n-\n20:15\nBengaluru\n12h 35m\n1 stop at Delhi\n13,052\nBook',
#  'Vistara\nUK - 974\nFlight Details\n05:30\nPune\n-\n11:50\nBengaluru\n6h 20m\n1 stop at Delhi\n13,556\nBook',
#  'Vistara\nUK - 974\nFlight Details\n05:30\nPune\n-\n23:20\nBengaluru\n17h 50m\n1 stop at Delhi\n13,608\nBook',
#  'Air India\nAI - 850\nFlight Details\n18:50\nPune\n-\n05:50\nBengaluru\narrives next day\n11h\n2 Stops (DEL, BOM)\n13,650\nBook',
#  'Vistara\nUK - 972\nFlight Details\n11:15\nPune\n-\n23:20\nBengaluru\n12h 5m\n1 stop at Delhi\n13,713\nBook',
#  'Vistara\nUK - 974\nFlight Details\n05:30\nPune\n-\n22:40\nBengaluru\n17h 10m\n1 stop at Delhi\n13,713\nBook',
#  'Vistara\nUK - 972\nFlight Details\n11:15\nPune\n-\n20:55\nBengaluru\n9h 40m\n2 Stops (DEL, BOM)\n17,703\nBook',
#  'Vistara\nUK - 972\nFlight Details\n11:15\nPune\n-\n21:35\nBengaluru\n10h 20m\n2 Stops (DEL, HYD)\n19,290\nBook',
#  'Vistara\nUK - 974\nFlight Details\n05:30\nPune\n-\n17:35\nBengaluru\narrives next day\n36h 5m\n2 Stops (DEL, GAU)\n20,215\nBook',
#  'Vistara\nUK - 972\nFlight Details\n11:15\nPune\n-\n17:35\nBengaluru\narrives next day\n30h 20m\n2 Stops (DEL, GAU)\n20,267\nBook',
#  'Vistara\nUK - 974\nFlight Details\n05:30\nPune\n-\n15:55\nBengaluru\n10h 25m\n2 Stops (DEL, GOI)\n20,323\nBook',
#  'Vistara\nUK - 972\nFlight Details\n11:15\nPune\n-\n23:20\nBengaluru\n12h 5m\n2 Stops (DEL, BOM)\n23,646\nBook',
#  'Vistara\nUK - 974\nFlight Details\n05:30\nPune\n-\n17:35\nBengaluru\n12h 5m\n3 Stops (DEL, DIB, GAU)\n36,855\nBook']

# %%
def paytm():
    flight1=driver.find_elements(By.XPATH,'//div[@class="_3215 row"]')
    airlinename=[]
    departure=[]
    source=[]
    timeofjourney=[]
    stop=[]
    arrival=[]
    destination=[]
    price=[]
    flight_name1=[]
    for i in flight1:
        flight_name1.append(i.text)
        airlinename.append(i.text.split('\n')[0])
        departure.append(i.text.split('\n')[3])
        source.append(i.text.split('\n')[4])
        destination.append(i.text.split('\n')[7])
        timeofjourney.append(i.text.split('\n')[8])
        stop.append(i.text.split('\n')[9])
        arrival.append(i.text.split('\n')[6])
        price.append(i.text.split('\n')[10])
        
    #price_tag=driver.find_elements(By.XPATH,'//p[@class="m-0 fs-5 fw-700 c-neutral-900 false"]')   
    #for i in price_tag:
        #price.append(i.text)
    df7=pd.DataFrame()
    df7['FLIGHT NAME']=airlinename
    df7['SOURCE']=source
    df7['DEPARTURE']=departure
    df7['ARRIVAL']=arrival
    df7['DESTINATION']=destination
    df7['TIME OF TRAVEL']=timeofjourney
    df7['NO. OF STOP']=stop
    df7['PRICE']=price    
    return(df7)

# %%
entersource2=driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div/div/div[1]/div[2]/div/div/div[2]/div/div[2]/div[1]/div[1]/input')
entersource2.click()

# %%
entersource2.send_keys("Pune")

# %%
enterdestin2=driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div/div/div[1]/div[2]/div/div/div[2]/div/div[4]/div[1]/div[1]/input')
enterdestin2.click()

# %%
enterdestin2.send_keys("Bangalore")

# %%
date9=[]
flight1=driver.find_elements(By.XPATH,'//div[@class="_3215 row"]')
for i in flight1:
    date9.append("14 May 2023")

# %%
df10=paytm()
df10["DATE"]=date9
dffinal=dffinal.append(df10,ignore_index = True)

# %%
dffinal
# Out:
#     FLIGHT NAME   SOURCE DESTINATION ARRIVAL DEPARTURE    TIME OF TRAVEL  \
# 0       AirAsia  Chennai   Bangalore   13:50     12:55           00h 55m
# 1       AirAsia  Chennai   Bangalore   08:10     07:10           01h 00m
# 2       AirAsia  Chennai   Bangalore   22:55     21:50           01h 05m
# 3        Indigo  Chennai   Bangalore   12:15     11:20           00h 55m
# 4        Indigo  Chennai   Bangalore   08:30     07:40           00h 50m
# ..          ...      ...         ...     ...       ...               ...
# 629     Vistara     Pune   Bengaluru   17:35     05:30  arrives next day
# 630     Vistara     Pune   Bengaluru   17:35     11:15  arrives next day
# 631     Vistara     Pune   Bengaluru   15:55     05:30           10h 25m
# 632     Vistara     Pune   Bengaluru   23:20     11:15            12h 5m
# 633     Vistara     Pune   Bengaluru   17:35     05:30            12h 5m
#
#                  NO. OF STOP               PRICE         DATE
# 0                   non-stop               1,718       Apr 18
# 1                   non-stop               1,933       Apr 18
# 2                   non-stop               1,933       Apr 18
# 3                   non-stop               1,825       Apr 18
# 4                   non-stop               2,040       Apr 18
# ..                       ...                 ...          ...
# 629                   36h 5m  2 Stops (DEL, GAU)  14 May 2023
# 630                  30h 20m  2 Stops (DEL, GAU)  14 May 2023
# 631       2 Stops (DEL, GOI)              20,323  14 May 2023
# 632       2 Stops (DEL, BOM)              23,646  14 May 2023
# 633  3 Stops (DEL, DIB, GAU)              36,855  14 May 2023
#
# [634 rows x 9 columns]

# %%
dffinal.to_csv('fight301.csv')

# %%
entersource3=driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div/div/div[1]/div[2]/div/div/div[2]/div/div[2]/div[1]/div[1]/input')
entersource3.click()

# %%
entersource3.send_keys("Bangalore")

# %%
enterdestin3=driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div/div/div[1]/div[2]/div/div/div[2]/div/div[4]/div[1]/div[1]/input')
enterdestin3.click()

# %%
enterdestin3.send_keys("Pune")

# %%
date10=[]
flight1=driver.find_elements(By.XPATH,'//div[@class="_3215 row"]')
for i in flight1:
    date10.append("22 April 2023")

# %%
df11=paytm()
df11["DATE"]=date10
dffinal=dffinal.append(df11,ignore_index = True)

# %%
dffinal
# Out:
#     FLIGHT NAME     SOURCE DESTINATION ARRIVAL DEPARTURE    TIME OF TRAVEL  \
# 0       AirAsia    Chennai   Bangalore   13:50     12:55           00h 55m
# 1       AirAsia    Chennai   Bangalore   08:10     07:10           01h 00m
# 2       AirAsia    Chennai   Bangalore   22:55     21:50           01h 05m
# 3        Indigo    Chennai   Bangalore   12:15     11:20           00h 55m
# 4        Indigo    Chennai   Bangalore   08:30     07:40           00h 50m
# ..          ...        ...         ...     ...       ...               ...
# 732   Air India  Bengaluru        Pune   18:10     05:45           12h 25m
# 733     Vistara  Bengaluru        Pune   00:35     09:30  arrives next day
# 734     Vistara  Bengaluru        Pune   12:35     09:30  arrives next day
# 735   Air India  Bengaluru        Pune   18:10     09:20            8h 50m
# 736     Vistara  Bengaluru        Pune   19:45     11:30            8h 15m
#
#             NO. OF STOP                    PRICE           DATE
# 0              non-stop                    1,718         Apr 18
# 1              non-stop                    1,933         Apr 18
# 2              non-stop                    1,933         Apr 18
# 3              non-stop                    1,825         Apr 18
# 4              non-stop                    2,040         Apr 18
# ..                  ...                      ...            ...
# 732     1 stop at Delhi                   22,143  22 April 2023
# 733              15h 5m  3 Stops (BOM, DED, DEL)  22 April 2023
# 734              27h 5m  3 Stops (BOM, DED, DEL)  22 April 2023
# 735  2 Stops (BOM, DEL)                   26,343  22 April 2023
# 736  2 Stops (IXC, DEL)                   31,199  22 April 2023
#
# [737 rows x 9 columns]

# %%
dffinal.to_csv('fight302.csv')

# %%
source=driver.find_element(By.XPATH,'//div[@class="fl-input-clear"]')
source.click()

# %%
entersource4=driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div/div/div[1]/div[2]/div/div/div[2]/div/div[2]/div[1]/div[1]/input')
entersource4.click()

# %%
entersource4.send_keys("Delhi")

# %%
enterdestin4=driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div/div/div[1]/div[2]/div/div/div[2]/div/div[4]/div[1]/div[1]/input')
enterdestin4.click()

# %%
enterdestin4.send_keys("Pune")

# %%
date11=[]
flight1=driver.find_elements(By.XPATH,'//div[@class="_3215 row"]')
for i in flight1:
    date11.append("24 May 2023")

# %%
df12=paytm()
df12["DATE"]=date11
dffinal=dffinal.append(df12,ignore_index = True)

# %%
dffinal
# Out:
#     FLIGHT NAME   SOURCE DESTINATION ARRIVAL DEPARTURE    TIME OF TRAVEL  \
# 0       AirAsia  Chennai   Bangalore   13:50     12:55           00h 55m
# 1       AirAsia  Chennai   Bangalore   08:10     07:10           01h 00m
# 2       AirAsia  Chennai   Bangalore   22:55     21:50           01h 05m
# 3        Indigo  Chennai   Bangalore   12:15     11:20           00h 55m
# 4        Indigo  Chennai   Bangalore   08:30     07:40           00h 50m
# ..          ...      ...         ...     ...       ...               ...
# 816      IndiGo    Delhi        Pune   04:10     18:35  arrives next day
# 817      IndiGo    Delhi        Pune   14:05     06:35            7h 30m
# 818      IndiGo    Delhi        Pune   01:35     19:20  arrives next day
# 819      IndiGo    Delhi        Pune   00:25     17:15  arrives next day
# 820      IndiGo    Delhi        Pune   00:25     15:05  arrives next day
#
#             NO. OF STOP                 PRICE         DATE
# 0              non-stop                 1,718       Apr 18
# 1              non-stop                 1,933       Apr 18
# 2              non-stop                 1,933       Apr 18
# 3              non-stop                 1,825       Apr 18
# 4              non-stop                 2,040       Apr 18
# ..                  ...                   ...          ...
# 816              9h 35m   1 stop at Ahmedabad  24 May 2023
# 817  1 stop at Dehradun                17,101  24 May 2023
# 818              6h 15m    1 stop at Amritsar  24 May 2023
# 819              7h 10m  1 stop at Chandigarh  24 May 2023
# 820              9h 20m  1 stop at Chandigarh  24 May 2023
#
# [821 rows x 9 columns]

# %%
dffinal.to_csv('fight303.csv')

# %%
entersource5=driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div[2]/div/div[1]/div/div/div[2]/div[2]/div[1]/div[1]/input')
entersource5.click()

# %%
entersource5.send_keys("Pune")

# %%
enterdestin5=driver.find_element(By.XPATH,'/html/body/div/div/div[2]/div/div[2]/div/div[1]/div/div/div[2]/div[4]/div[1]/div[1]/input')
enterdestin5.click()

# %%
enterdestin5.send_keys("Delhi")

# %%
date12=[]
flight1=driver.find_elements(By.XPATH,'//div[@class="_3215 row"]')
for i in flight1:
    date12.append("28 March 2023")

# %%
df13=paytm()
df13["DATE"]=date12
dffinal=dffinal.append(df13,ignore_index = True)

# %%
dffinal
# Out:
#     FLIGHT NAME   SOURCE DESTINATION ARRIVAL DEPARTURE    TIME OF TRAVEL  \
# 0       AirAsia  Chennai   Bangalore   13:50     12:55           00h 55m
# 1       AirAsia  Chennai   Bangalore   08:10     07:10           01h 00m
# 2       AirAsia  Chennai   Bangalore   22:55     21:50           01h 05m
# 3        Indigo  Chennai   Bangalore   12:15     11:20           00h 55m
# 4        Indigo  Chennai   Bangalore   08:30     07:40           00h 50m
# ..          ...      ...         ...     ...       ...               ...
# 896      IndiGo     Pune       Delhi   13:40     05:55            7h 45m
# 897      IndiGo     Pune       Delhi   06:55     02:15            4h 40m
# 898      IndiGo     Pune       Delhi   14:15     04:20            9h 55m
# 899   Air India     Pune       Delhi   04:10     11:20  arrives next day
# 900      IndiGo     Pune       Delhi   10:25     02:15            8h 10m
#
#               NO. OF STOP               PRICE           DATE
# 0                non-stop               1,718         Apr 18
# 1                non-stop               1,933         Apr 18
# 2                non-stop               1,933         Apr 18
# 3                non-stop               1,825         Apr 18
# 4                non-stop               2,040         Apr 18
# ..                    ...                 ...            ...
# 896         1 stop at Goa              11,081  28 March 2023
# 897    1 stop at Amritsar              11,238  28 March 2023
# 898  1 stop at Chandigarh              11,679  28 March 2023
# 899               16h 50m  2 Stops (BOM, GOI)  28 March 2023
# 900    1 stop at Amritsar              13,649  28 March 2023
#
# [901 rows x 9 columns]

# %%
dffinal.to_csv('fight304.csv')

# %% [markdown]
# MERGING BOTH THE DATA FRAME INTO ONE

# %%
dfpart1=pd.DataFrame()
dfpart2=pd.DataFrame()
dfcomplete=pd.DataFrame()

# %%
dfpart1=pd.read_csv('flight117.csv')
dfpart1.head()
# Out:
#    Unnamed: 0 FLIGHT NAME SOURCE DESTINATION ARRIVAL DEPARTURE TIME OF TRAVEL  \
# 0           0     AirAsia  Delhi      Mumbai   02:15     19:05        07h 10m
# 1           1    GO FIRST  Delhi      Mumbai   04:50     02:40        02h 10m
# 2           2    GO FIRST  Delhi      Mumbai   09:40     07:25        02h 15m
# 3           3    GO FIRST  Delhi      Mumbai   23:45     21:30        02h 15m
# 4           4    GO FIRST  Delhi      Mumbai   01:00     22:45        02h 15m
#
#   NO. OF STOP  PRICE    DATE
# 0     2+-stop  3,987  Mar-30
# 1    non-stop  4,202  Mar-30
# 2    non-stop  4,202  Mar-30
# 3    non-stop  4,202  Mar-30
# 4    non-stop  4,202  Mar-30

# %%
dfpart2=pd.read_csv('fight304.csv')
dfpart2.head()
# Out:
#    Unnamed: 0 FLIGHT NAME   SOURCE DESTINATION ARRIVAL DEPARTURE  \
# 0           0     AirAsia  Chennai   Bangalore   13:50     12:55
# 1           1     AirAsia  Chennai   Bangalore   08:10     07:10
# 2           2     AirAsia  Chennai   Bangalore   22:55     21:50
# 3           3      Indigo  Chennai   Bangalore   12:15     11:20
# 4           4      Indigo  Chennai   Bangalore   08:30     07:40
#
#   TIME OF TRAVEL NO. OF STOP  PRICE    DATE
# 0        00h 55m    non-stop  1,718  Apr 18
# 1        01h 00m    non-stop  1,933  Apr 18
# 2        01h 05m    non-stop  1,933  Apr 18
# 3        00h 55m    non-stop  1,825  Apr 18
# 4        00h 50m    non-stop  2,040  Apr 18

# %%
frames = [dfpart1, dfpart2]
  
dfcomplete = pd.concat(frames,ignore_index=True)

# %%
dfcomplete
# Out:
#       Unnamed: 0 FLIGHT NAME SOURCE DESTINATION ARRIVAL DEPARTURE  \
# 0              0     AirAsia  Delhi      Mumbai   02:15     19:05
# 1              1    GO FIRST  Delhi      Mumbai   04:50     02:40
# 2              2    GO FIRST  Delhi      Mumbai   09:40     07:25
# 3              3    GO FIRST  Delhi      Mumbai   23:45     21:30
# 4              4    GO FIRST  Delhi      Mumbai   01:00     22:45
# ...          ...         ...    ...         ...     ...       ...
# 1840         896      IndiGo   Pune       Delhi   13:40     05:55
# 1841         897      IndiGo   Pune       Delhi   06:55     02:15
# 1842         898      IndiGo   Pune       Delhi   14:15     04:20
# 1843         899   Air India   Pune       Delhi   04:10     11:20
# 1844         900      IndiGo   Pune       Delhi   10:25     02:15
#
#         TIME OF TRAVEL           NO. OF STOP               PRICE  \
# 0              07h 10m               2+-stop               3,987
# 1              02h 10m              non-stop               4,202
# 2              02h 15m              non-stop               4,202
# 3              02h 15m              non-stop               4,202
# 4              02h 15m              non-stop               4,202
# ...                ...                   ...                 ...
# 1840            7h 45m         1 stop at Goa              11,081
# 1841            4h 40m    1 stop at Amritsar              11,238
# 1842            9h 55m  1 stop at Chandigarh              11,679
# 1843  arrives next day               16h 50m  2 Stops (BOM, GOI)
# 1844            8h 10m    1 stop at Amritsar              13,649
#
#                DATE
# 0            Mar-30
# 1            Mar-30
# 2            Mar-30
# 3            Mar-30
# 4            Mar-30
# ...             ...
# 1840  28 March 2023
# 1841  28 March 2023
# 1842  28 March 2023
# 1843  28 March 2023
# 1844  28 March 2023
#
# [1845 rows x 10 columns]

# %%
dfcomplete.to_csv('dataflight.csv')
